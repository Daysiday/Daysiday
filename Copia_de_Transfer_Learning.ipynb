# %% [markdown]
# <a href="https://colab.research.google.com/github/Daysiday/Daysiday/blob/main/Copia_de_Transfer_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Crear las carpetas para subir las imagenes
# !mkdir cuchillos
# !mkdir tenedores
# !mkdir cucharas

# %%
#Entrar en cada carpeta y descomprimir el archivo zip
# %cd cuchillos
# !unzip cuchillos.zip
# %cd ..

# %cd tenedores
# !unzip tenedores.zip
# %cd ..

# %cd cucharas
# !unzip cucharas.zip
# %cd ..
# Out:
# /content/cuchillos
# Archive:  cuchillos.zip
#   inflating: cuchillo (1).jpg
#   inflating: cuchillo (2).jpg
#   inflating: cuchillo (3).jpg
#   inflating: cuchillo (4).jpg
#   inflating: cuchillo (5).jpg
#   inflating: cuchillo (6).jpg
#   inflating: cuchillo (7).jpg
#   inflating: cuchillo (8).jpg
#   inflating: cuchillo (9).jpg
#   inflating: cuchillo (10).jpg
#   inflating: cuchillo (11).jpg
#   inflating: cuchillo (12).jpg
#   inflating: cuchillo (13).jpg
#   inflating: cuchillo (14).jpg
#   inflating: cuchillo (15).jpg
#   inflating: cuchillo (16).jpg
#   inflating: cuchillo (17).jpg
#   inflating: cuchillo (18).jpg
#   inflating: cuchillo (19).jpg
#   inflating: cuchillo (20).jpg
#   inflating: cuchillo (21).jpg
#   inflating: cuchillo (22).jpg
#   inflating: cuchillo (23).jpg
#   inflating: cuchillo (24).jpg
#   inflating: cuchillo (25).jpg
#   inflating: cuchillo (26).jpg
#   inflating: cuchillo (27).jpg
#   inflating: cuchillo (28).jpg
#   inflating: cuchillo (29).jpg
#   inflating: cuchillo (30).jpg
#   inflating: cuchillo (31).jpg
#   inflating: cuchillo (32).jpg
#   inflating: cuchillo (33).jpg
#   inflating: cuchillo (34).jpg
#   inflating: cuchillo (35).jpg
#   inflating: cuchillo (36).jpg
#   inflating: cuchillo (37).jpg
#   inflating: cuchillo (38).jpg
#   inflating: cuchillo (39).jpg
#   inflating: cuchillo (40).jpg
#   inflating: cuchillo (41).jpg
#   inflating: cuchillo (42).jpg
#   inflating: cuchillo (43).jpg
#   inflating: cuchillo (44).jpg
#   inflating: cuchillo (45).jpg
#   inflating: cuchillo (46).jpg
#   inflating: cuchillo (47).jpg
#   inflating: cuchillo (48).jpg
#   inflating: cuchillo (49).jpg
#   inflating: cuchillo (50).jpg
#   inflating: cuchillo (51).jpg
#   inflating: cuchillo (52).jpg
#   inflating: cuchillo (53).jpg
#   inflating: cuchillo (54).jpg
#   inflating: cuchillo (55).jpg
#   inflating: cuchillo (56).jpg
#   inflating: cuchillo (57).jpg
#   inflating: cuchillo (58).jpg
#   inflating: cuchillo (59).jpg
#   inflating: cuchillo (60).jpg
#   inflating: cuchillo (61).jpg
#   inflating: cuchillo (62).jpg
#   inflating: cuchillo (63).jpg
#   inflating: cuchillo (64).jpg
#   inflating: cuchillo (65).jpg
#   inflating: cuchillo (66).jpg
#   inflating: cuchillo (67).jpg
#   inflating: cuchillo (68).jpg
#   inflating: cuchillo (69).jpg
#   inflating: cuchillo (70).jpg
#   inflating: cuchillo (71).jpg
#   inflating: cuchillo (72).jpg
#   inflating: cuchillo (73).jpg
#   inflating: cuchillo (74).jpg
#   inflating: cuchillo (75).jpg
#   inflating: cuchillo (76).jpg
#   inflating: cuchillo (77).jpg
#   inflating: cuchillo (78).jpg
#   inflating: cuchillo (79).jpg
#   inflating: cuchillo (80).jpg
#   inflating: cuchillo (81).jpg
#   inflating: cuchillo (82).jpg
#   inflating: cuchillo (83).jpg
#   inflating: cuchillo (84).jpg
#   inflating: cuchillo (85).jpg
#   inflating: cuchillo (86).jpg
#   inflating: cuchillo (87).jpg
#   inflating: cuchillo (88).jpg
#   inflating: cuchillo (89).jpg
#   inflating: cuchillo (90).jpg
#   inflating: cuchillo (91).jpg
#   inflating: cuchillo (92).jpg
#   inflating: cuchillo (93).jpg
#   inflating: cuchillo (94).jpg
#   inflating: cuchillo (95).jpg
#   inflating: cuchillo (96).jpg
#   inflating: cuchillo (97).jpg
#   inflating: cuchillo (98).jpg
#   inflating: cuchillo (99).jpg
#   inflating: cuchillo (100).jpg
# /content
# /content/tenedores
# Archive:  tenedores.zip
#   inflating: tenedor (1).jpg
#   inflating: tenedor (2).jpg
#   inflating: tenedor (3).jpg
#   inflating: tenedor (4).jpg
#   inflating: tenedor (5).jpg
#   inflating: tenedor (6).jpg
#   inflating: tenedor (7).jpg
#   inflating: tenedor (8).jpg
#   inflating: tenedor (9).jpg
#   inflating: tenedor (10).jpg
#   inflating: tenedor (11).jpg
#   inflating: tenedor (12).jpg
#   inflating: tenedor (13).jpg
#   inflating: tenedor (14).jpg
#   inflating: tenedor (15).jpg
#   inflating: tenedor (16).jpg
#   inflating: tenedor (17).jpg
#   inflating: tenedor (18).jpg
#   inflating: tenedor (19).jpg
#   inflating: tenedor (20).jpg
#   inflating: tenedor (21).jpg
#   inflating: tenedor (22).jpg
#   inflating: tenedor (23).jpg
#   inflating: tenedor (24).jpg
#   inflating: tenedor (25).jpg
#   inflating: tenedor (26).jpg
#   inflating: tenedor (27).jpg
#   inflating: tenedor (28).jpg
#   inflating: tenedor (29).jpg
#   inflating: tenedor (30).jpg
#   inflating: tenedor (31).jpg
#   inflating: tenedor (32).jpg
#   inflating: tenedor (33).jpg
#   inflating: tenedor (34).jpg
#   inflating: tenedor (35).jpg
#   inflating: tenedor (36).jpg
#   inflating: tenedor (37).jpg
#   inflating: tenedor (38).jpg
#   inflating: tenedor (39).jpg
#   inflating: tenedor (40).jpg
#   inflating: tenedor (41).jpg
#   inflating: tenedor (42).jpg
#   inflating: tenedor (43).jpg
#   inflating: tenedor (44).jpg
#   inflating: tenedor (45).jpg
#   inflating: tenedor (46).jpg
#   inflating: tenedor (47).jpg
#   inflating: tenedor (48).jpg
#   inflating: tenedor (49).jpg
#   inflating: tenedor (50).jpg
#   inflating: tenedor (51).jpg
#   inflating: tenedor (52).jpg
#   inflating: tenedor (53).jpg
#   inflating: tenedor (54).jpg
#   inflating: tenedor (55).jpg
#   inflating: cuchara (77).jpg
#   inflating: cuchara (78).jpg
#   inflating: cuchara (79).jpg
#   inflating: cuchara (80).jpg
#   inflating: cuchara (81).jpg
#   inflating: cuchara (82).jpg
#   inflating: cuchara (83).jpg
#   inflating: cuchara (84).jpg
#   inflating: cuchara (85).jpg
#   inflating: cuchara (86).jpg
#   inflating: cuchara (87).jpg
#   inflating: cuchara (88).jpg
#   inflating: cuchara (89).jpg
#   inflating: cuchara (90).jpg
#   inflating: cuchara (91).jpg
#   inflating: cuchara (92).jpg
#   inflating: cuchara (93).jpg
#   inflating: cuchara (94).jpg
#   inflating: cuchara (95).jpg
#   inflating: cuchara (96).jpg
#   inflating: cuchara (97).jpg
#   inflating: cuchara (98).jpg
#   inflating: cuchara (99).jpg
#   inflating: cuchara (100).jpg
#   inflating: cuchara (1).jpg
#   inflating: cuchara (2).jpg
#   inflating: cuchara (3).jpg
#   inflating: cuchara (4).jpg
#   inflating: cuchara (5).jpg
#   inflating: cuchara (6).jpg
#   inflating: cuchara (7).jpg
#   inflating: cuchara (8).jpg
#   inflating: cuchara (9).jpg
#   inflating: cuchara (10).jpg
#   inflating: cuchara (11).jpg
#   inflating: cuchara (12).jpg
#   inflating: cuchara (13).jpg
#   inflating: cuchara (14).jpg
#   inflating: cuchara (15).jpg
#   inflating: cuchara (16).jpg
#   inflating: cuchara (17).jpg
#   inflating: cuchara (18).jpg
#   inflating: cuchara (19).jpg
#   inflating: cuchara (20).jpg
#   inflating: cuchara (21).jpg
#   inflating: cuchara (22).jpg
#   inflating: cuchara (23).jpg
#   inflating: cuchara (24).jpg
#   inflating: cuchara (25).jpg
#   inflating: cuchara (26).jpg
#   inflating: cuchara (27).jpg
#   inflating: cuchara (28).jpg
#   inflating: cuchara (29).jpg
#   inflating: cuchara (30).jpg
#   inflating: cuchara (31).jpg
#   inflating: cuchara (32).jpg
#   inflating: cuchara (33).jpg
#   inflating: cuchara (34).jpg
# /content

# %%
#Eliminar alguna carpeta
# !rm -fr #ruta de la carpeta

# %%
#Borrar los archivo ZIP
# !rm -rf /content/cucharas/cucharas.zip
# !rm -rf /content/cuchillos/cuchillos.zip
# !rm -rf /content/tenedores/tenedores.zip

# %%
#Mostrar cuantas imagenes tengo de cada categoria
# !ls /content/cucharas | wc -l #100
# !ls /content/cuchillos | wc -l #100
# !ls /content/tenedores | wc -l #100
# Out:
# 100
# 100
# 100

# %%
#Mostrar algunas imagenes con pyplot
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

carpeta = "/content/cuchillos"
imagenes = sorted(os.listdir(carpeta))  # Lista de archivos en la carpeta

# Filtrar solo archivos de imagen (evitar directorios)
imagenes = [img for img in imagenes if os.path.isfile(os.path.join(carpeta, img))]

# Graficar las primeras 25 imágenes
plt.figure(figsize=(10, 10))
for i, nombreimg in enumerate(imagenes[:20]):
    plt.subplot(5, 5, i + 1)
    imagen = mpimg.imread(os.path.join(carpeta, nombreimg))
    plt.imshow(imagen)
    plt.axis("off")  # Ocultar ejes
plt.show()

# %%
#Crear carpetas para hacer el set de datos

# !mkdir dataset
# !mkdir dataset/cuchillo
# !mkdir dataset/tenedor
# !mkdir dataset/cuchara

# %%
#Copiar imagenes que subimos a carpetas del dataset
#Limitar para que todos tengan la misma cantidad de imagenes
#maximo 100 (el num. menor de imagenes que subi)

import os
import shutil

carpeta_fuente = "/content/cuchillos/"
carpeta_destino = "/content/dataset/cuchillo"

# Crear la carpeta de destino si no existe
os.makedirs(carpeta_destino, exist_ok=True)

# Obtener la lista de archivos en la carpeta fuente
imagenes = sorted(os.listdir(carpeta_fuente))

# Filtrar solo archivos de imagen (evitar directorios)
imagenes = [img for img in imagenes if os.path.isfile(os.path.join(carpeta_fuente, img))]

# Copiar los primeros 100 archivos
for i, nombreimg in enumerate(imagenes[:100]):
    shutil.copy(os.path.join(carpeta_fuente, nombreimg), os.path.join(carpeta_destino, nombreimg))

print("Copia completada con éxito.")
# Out:
# Copia completada con éxito.

# %%
import os
import shutil

carpeta_fuente = "/content/cucharas"
carpeta_destino = "/content/dataset/cuchara"

# Crear la carpeta de destino si no existe
os.makedirs(carpeta_destino, exist_ok=True)

# Obtener la lista de archivos en la carpeta fuente
imagenes = sorted(os.listdir(carpeta_fuente))

# Filtrar solo archivos de imagen (evitar directorios)
imagenes = [img for img in imagenes if os.path.isfile(os.path.join(carpeta_fuente, img))]

# Copiar los primeros 100 archivos
for i, nombreimg in enumerate(imagenes[:100]):
    shutil.copy(os.path.join(carpeta_fuente, nombreimg), os.path.join(carpeta_destino, nombreimg))

print("Copia completada con éxito.")
# Out:
# Copia completada con éxito.

# %%
import os
import shutil

carpeta_fuente = "/content/tenedores"
carpeta_destino = "/content/dataset/tenedor"

# Crear la carpeta de destino si no existe
os.makedirs(carpeta_destino, exist_ok=True)

# Obtener la lista de archivos en la carpeta fuente
imagenes = sorted(os.listdir(carpeta_fuente))

# Filtrar solo archivos de imagen (evitar directorios)
imagenes = [img for img in imagenes if os.path.isfile(os.path.join(carpeta_fuente, img))]

# Copiar los primeros 100 archivos
for i, nombreimg in enumerate(imagenes[:100]):
    shutil.copy(os.path.join(carpeta_fuente, nombreimg), os.path.join(carpeta_destino, nombreimg))

print("Copia completada con éxito.")
# Out:
# Copia completada con éxito.

# %%
#Mostrar cuantas imagenes tengo de cada categoria en el dataset
# !ls /content/dataset/cuchara | wc -l
# !ls /content/dataset/cuchillo | wc -l
# !ls /content/dataset/tenedor | wc -l
# Out:
# 100
# 100
# 100

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Definir el tamaño de las imágenes y el tamaño de lote
IMG_SIZE = 160  # Tamaño de entrada para MobileNetV2 (160x160 píxeles)
BATCH_SIZE = 32  # Cantidad de imágenes procesadas en cada iteración

# Crear un generador de imágenes con preprocesamiento
datagen = ImageDataGenerator(
    rescale=1.0/255,  # Normaliza los valores de los píxeles al rango [0,1]
    validation_split=0.2  # Separa el 20% de las imágenes para validación
)

# Cargar imágenes de entrenamiento en lotes desde la carpeta 'dataset'
train_data = datagen.flow_from_directory(
    "dataset",  # Ruta del dataset que contiene subcarpetas para cada clase
    target_size=(IMG_SIZE, IMG_SIZE),  # Redimensiona imágenes al tamaño esperado por el modelo
    batch_size=BATCH_SIZE,  # Número de imágenes por lote
    class_mode="categorical",  # Indica que hay múltiples clases (categórico = one-hot encoding)
    subset="training"  # Usa el 80% de las imágenes para entrenamiento
)

# Cargar imágenes de validación en lotes
val_data = datagen.flow_from_directory(
    "dataset",  # Mismo dataset, pero con el conjunto de validación
    target_size=(IMG_SIZE, IMG_SIZE),  # Redimensiona al mismo tamaño
    batch_size=BATCH_SIZE,  # Lote de imágenes para validación
    class_mode="categorical",  # Clasificación con múltiples clases
    subset="validation"  # Usa el 20% de las imágenes para validación
)

# Mostrar las clases detectadas y su índice asignado
print(train_data.class_indices)
# Salida esperada: {'cucharas': 0, 'tenedores': 1, 'cuchillos': 2}
# Out:
# Found 240 images belonging to 3 classes.
# Found 60 images belonging to 3 classes.
# {'cuchara': 0, 'cuchillo': 1, 'tenedor': 2}

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Cargar MobileNetV2 sin la última capa de clasificación
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(IMG_SIZE, IMG_SIZE, 3),  # Dimensiones de entrada (160x160 píxeles, 3 canales RGB)
    include_top=False,  # No incluir la última capa completamente conectada (para personalizar la clasificación)
    weights="imagenet"  # Usar pesos preentrenados en ImageNet
)

# Congelar las capas del modelo base para mantener los pesos preentrenados
base_model.trainable = False

# Construcción del modelo final agregando capas personalizadas
model = models.Sequential([
    base_model,  # Se usa MobileNetV2 como extractor de características
    layers.GlobalAveragePooling2D(),  # Convierte los mapas de características en un vector de tamaño fijo
    layers.Dense(128, activation="relu"),  # Capa densa con 128 neuronas y activación ReLU para que las redes neuronales aprenda representaciones complejas
    layers.Dropout(0.2),  # implica que el 20% de las neuronas en esa capa se desactivarán aleatoriamente durante el entrenamiento, ayudando a prevenir el sobreajuste.
    layers.Dense(3, activation="softmax")  # Capa de salida con 3 neuronas (para cucharas, tenedores y cuchillos)
])

# Compilar el modelo con función de pérdida y optimizador
model.compile(optimizer="adam",  # Optimizador Adam para aprendizaje eficiente
              loss="categorical_crossentropy",  # Pérdida para clasificación multiclase
              metrics=["accuracy"])  # Métrica de evaluación: precisión (accuracy)

# Mostrar resumen del modelo (estructura y cantidad de parámetros)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_160_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_160 (Functional)    │ (None, 5, 5, 1280)          │       2,257,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         163,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │             387 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,422,339 (9.24 MB)
#  Trainable params: 164,355 (642.01 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
# Entrenar el modelo
history = model.fit(
    train_data,  # Datos de entrenamiento (usados para entrenar el modelo)
    epochs=50,  # Número de épocas (cuántas veces se entrenará el modelo sobre todo el dataset)
    validation_data=val_data  # Datos de validación (usados para evaluar el modelo en cada época)
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.5788 - loss: 0.8651 - val_accuracy: 0.9500 - val_loss: 0.1354
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - accuracy: 0.9726 - loss: 0.0765 - val_accuracy: 0.9833 - val_loss: 0.0558
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s
50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 1.0000 - loss: 5.4649e-04 - val_accuracy: 0.9667 - val_loss: 0.0815
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 1.0000 - loss: 1.9752e-04 - val_accuracy: 0.9667 - val_loss: 0.0832
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 1.0000 - loss: 3.4627e-04 - val_accuracy: 0.9667 - val_loss: 0.0846
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 1.0000 - loss: 3.6614e-04 - val_accuracy: 0.9833 - val_loss: 0.0851
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 1.0000 - loss: 2.6917e-04 - val_accuracy: 0.9833 - val_loss: 0.0847
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step - accuracy: 1.0000 - loss: 4.0543e-04 - val_accuracy: 0.9833 - val_loss: 0.0849
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 173ms/step - accuracy: 1.0000 - loss: 2.7701e-04 - val_accuracy: 0.9833 - val_loss: 0.0821
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 185ms/step - accuracy: 1.0000 - loss: 3.2810e-04 - val_accuracy: 0.9833 - val_loss: 0.0804
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 1.0000 - loss: 1.8270e-04 - val_accuracy: 0.9833 - val_loss: 0.0796
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - accuracy: 1.0000 - loss: 1.5693e-04 - val_accuracy: 0.9833 - val_loss: 0.0800
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 1.0000 - loss: 1.8247e-04 - val_accuracy: 0.9833 - val_loss: 0.0801
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - accuracy: 1.0000 - loss: 1.6843e-04 - val_accuracy: 0.9833 - val_loss: 0.0817
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - accuracy: 1.0000 - loss: 1.8300e-04 - val_accuracy: 0.9833 - val_loss: 0.0828
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 246ms/step - accuracy: 1.0000 - loss: 2.2908e-04 - val_accuracy: 0.9833 - val_loss: 0.0852
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 187ms/step - accuracy: 1.0000 - loss: 1.6724e-04 - val_accuracy: 0.9833 - val_loss: 0.0857
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - accuracy: 1.0000 - loss: 1.2316e-04 - val_accuracy: 0.9833 - val_loss: 0.0862
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - accuracy: 1.0000 - loss: 2.6258e-04 - val_accuracy: 0.9833 - val_loss: 0.0871
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - accuracy: 1.0000 - loss: 2.1545e-04 - val_accuracy: 0.9833 - val_loss: 0.0885

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

# Cargar una imagen de prueba
img_path = "/content/T1.jpeg"  # Cambia por una imagen de prueba
img = image.load_img(img_path, target_size=(IMG_SIZE, IMG_SIZE))

# Convertir la imagen a un array y preprocesarla
img_array = image.img_to_array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

# Hacer predicción
predictions = model.predict(img_array)
predicted_class = np.argmax(predictions)

# Mostrar la predicción
class_labels = list(train_data.class_indices.keys())  # Obtener nombres de clases
predicted_label = class_labels[predicted_class]

# Graficar la imagen con la predicción
plt.imshow(img)
plt.axis("off")
plt.title(f"Predicción: {predicted_label}", fontsize=14, fontweight="bold")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
